# %% [markdown]
# # Passo a passo
#
# 1- ler os dados da planilha excel
# 2-

# %%
import pandas as pd

# %%
base = pd.read_excel('planilha_alunos.xlsx')
display(base)
# Out:
#                Nome do Curso        Nome Participante Tipo de Participação  \
# 0   Introdução à Programação         Ana Santos Gomes          Palestrante
# 1   Introdução à Programação   Carlos Rodrigues Gomes          Organizador
# 2   Introdução à Programação  Aline Almeida Fernandes          Palestrante
# 3   Introdução à Programação   Paulo Oliveira Pereira              Ouvinte
# 4   Introdução à Programação     Felipe Almeida Souza              Ouvinte
# ..                       ...                      ...                  ...
# 95  Introdução à Programação   Camila Rodrigues Silva          Organizador
# 96  Introdução à Programação       Luana Lima Almeida              Ouvinte
# 97  Introdução à Programação      Luana Souza Almeida          Palestrante
# 98  Introdução à Programação   Felipe Silva Rodrigues          Palestrante
# 99  Introdução à Programação       Julia Santos Silva              Ouvinte
#
#    Data de Início Data de Término  Carga Horária (horas)  \
# ...

# %%
pip install pandas
# Out:
# ...
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.6 MB 1.5 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/11.6 MB 1.5 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/11.6 MB 1.5 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/11.6 MB 1.5 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/11.6 MB 481.4 kB/s eta 0:00:24
#     --------------------------------------- 0.2/11.6 MB 492.3 kB/s eta 0:00:24
# ...
